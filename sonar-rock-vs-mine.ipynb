# %% [markdown]
# <a href="https://www.kaggle.com/code/vinnela20/sonar-rock-vs-mine?scriptVersionId=191528558" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/connectionist-bench-sonar-mines-vs-rocks/sonar.all-data.csv

# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input/connectionist-bench-sonar-mines-vs-rocks'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/connectionist-bench-sonar-mines-vs-rocks/sonar.all-data.csv

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collectin and Data Processing

# %%
#loading the dataset to as pandas DataFrame
sonar_data = pd.read_csv("/kaggle/input/connectionist-bench-sonar-mines-vs-rocks/sonar.all-data.csv",header=None)

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  Freq_1  Freq_2  Freq_3  Freq_4  Freq_5  Freq_6  Freq_7  Freq_8  Freq_9
# 1    0.02  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 2  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 3  0.0262  0.0582  0.1099  0.1083  0.0974   0.228  0.2431  0.3771  0.5598
# 4    0.01  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
#
#         9   ...       51       52       53       54       55       56  \
# 0  Freq_10  ...  Freq_52  Freq_53  Freq_54  Freq_55  Freq_56  Freq_57
# 1   0.2111  ...   0.0027   0.0065   0.0159   0.0072   0.0167    0.018
# 2   0.2872  ...   0.0084   0.0089   0.0048   0.0094   0.0191    0.014
# 3   0.6194  ...   0.0232   0.0166   0.0095    0.018   0.0244   0.0316
# 4   0.1264  ...   0.0121   0.0036    0.015   0.0085   0.0073    0.005
#
#         57       58       59     60
# 0  Freq_58  Freq_59  Freq_60  Label
# 1   0.0084    0.009   0.0032      R
# 2   0.0049   0.0052   0.0044      R
# 3   0.0164   0.0095   0.0078      R
# 4   0.0044    0.004   0.0117      R
#
# [5 rows x 61 columns]

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  Freq_1  Freq_2  Freq_3  Freq_4  Freq_5  Freq_6  Freq_7  Freq_8  Freq_9
# 1    0.02  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 2  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 3  0.0262  0.0582  0.1099  0.1083  0.0974   0.228  0.2431  0.3771  0.5598
# 4    0.01  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
#
#         9   ...       51       52       53       54       55       56  \
# 0  Freq_10  ...  Freq_52  Freq_53  Freq_54  Freq_55  Freq_56  Freq_57
# 1   0.2111  ...   0.0027   0.0065   0.0159   0.0072   0.0167    0.018
# 2   0.2872  ...   0.0084   0.0089   0.0048   0.0094   0.0191    0.014
# 3   0.6194  ...   0.0232   0.0166   0.0095    0.018   0.0244   0.0316
# 4   0.1264  ...   0.0121   0.0036    0.015   0.0085   0.0073    0.005
#
#         57       58       59     60
# 0  Freq_58  Freq_59  Freq_60  Label
# 1   0.0084    0.009   0.0032      R
# 2   0.0049   0.0052   0.0044      R
# 3   0.0164   0.0095   0.0078      R
# 4   0.0044    0.004   0.0117      R
#
# [5 rows x 61 columns]

# %%
#number of rows and columns
sonar_data.shape
# Out:
# (209, 61)

# %% [markdown]
# Describe  -----> Statistical measures of the data

# %%
sonar_data.describe()
# Out:
#             0       1       2       3      4       5       6       7       8   \
# count      209     209     209     209    209     209     209     209     209
# unique     178     183     191     182    194     197     196     202     206
# top     0.0201  0.0394  0.0476  0.0108  0.063  0.1267  0.0771  0.0664  0.0598
# freq         5       2       2       3      2       2       3       2       2
#
#             9   ...      51      52      53      54      55      56      57  \
# count      209  ...     209     209     209     209     209     209     209
# unique     208  ...     145     135     135     130     123     122     125
# top     0.2354  ...  0.0091  0.0129  0.0079  0.0075  0.0054  0.0037  0.0036
# freq         2  ...       5       5       5       5       5       7       6
#
#            58      59   60
# count     209     209  209
# unique    120     110    3
# top     0.007  0.0053    M
# freq        6       7  111
#
# [4 rows x 61 columns]

# %%
sonar_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       209 non-null    object
#  1   1       209 non-null    object
#  2   2       209 non-null    object
#  3   3       209 non-null    object
#  4   4       209 non-null    object
#  5   5       209 non-null    object
#  6   6       209 non-null    object
#  7   7       209 non-null    object
#  8   8       209 non-null    object
#  9   9       209 non-null    object
#  10  10      209 non-null    object
#  11  11      209 non-null    object
#  12  12      209 non-null    object
#  13  13      209 non-null    object
#  14  14      209 non-null    object
#  15  15      209 non-null    object
#  16  16      209 non-null    object
#  17  17      209 non-null    object
#  18  18      209 non-null    object
#  19  19      209 non-null    object
#  20  20      209 non-null    object
#  21  21      209 non-null    object
#  22  22      209 non-null    object
#  23  23      209 non-null    object
#  24  24      209 non-null    object
#  25  25      209 non-null    object
#  26  26      209 non-null    object
#  27  27      209 non-null    object
#  28  28      209 non-null    object
#  29  29      209 non-null    object
#  30  30      209 non-null    object
#  31  31      209 non-null    object
#  32  32      209 non-null    object
#  33  33      209 non-null    object
#  34  34      209 non-null    object
#  35  35      209 non-null    object
#  36  36      209 non-null    object
#  37  37      209 non-null    object
#  38  38      209 non-null    object
#  39  39      209 non-null    object
#  40  40      209 non-null    object
#  41  41      209 non-null    object
#  42  42      209 non-null    object
#  43  43      209 non-null    object
#  44  44      209 non-null    object
#  45  45      209 non-null    object
#  46  46      209 non-null    object
#  47  47      209 non-null    object
#  48  48      209 non-null    object
#  49  49      209 non-null    object
#  50  50      209 non-null    object
#  51  51      209 non-null    object
#  52  52      209 non-null    object
#  53  53      209 non-null    object
#  54  54      209 non-null    object
#  55  55      209 non-null    object
#  56  56      209 non-null    object
#  57  57      209 non-null    object
#  58  58      209 non-null    object
#  59  59      209 non-null    object
#  60  60      209 non-null    object
# dtypes: object(61)
# memory usage: 99.7+ KB

# %%
sonar_data=sonar_data.drop(index=0, axis=0)

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 1    0.02  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 2  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 3  0.0262  0.0582  0.1099  0.1083  0.0974   0.228  0.2431  0.3771  0.5598
# 4    0.01  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 5  0.0762  0.0666  0.0481  0.0394   0.059  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 1  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167   0.018  0.0084
# 2  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191   0.014  0.0049
# 3  0.6194  ...  0.0232  0.0166  0.0095   0.018  0.0244  0.0316  0.0164
# 4  0.1264  ...  0.0121  0.0036   0.015  0.0085  0.0073   0.005  0.0044
# 5  0.4459  ...  0.0031  0.0054  0.0105   0.011  0.0015  0.0072  0.0048
#
#        58      59 60
# 1   0.009  0.0032  R
# 2  0.0052  0.0044  R
# 3  0.0095  0.0078  R
# 4   0.004  0.0117  R
# 5  0.0107  0.0094  R
#
# [5 rows x 61 columns]

# %%
sonar_data.shape
# Out:
# (208, 61)

# %%
sonar_data[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %% [markdown]
# M -> Mine
#
# R -> Rock

# %%
#separating data and labels
X=sonar_data.drop(columns=60, axis=1)
Y=sonar_data[60]

# %%
print(X)
print(Y)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 1      0.02  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 2    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 3    0.0262  0.0582  0.1099  0.1083  0.0974   0.228  0.2431  0.3771  0.5598
# 4      0.01  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 5    0.0762  0.0666  0.0481  0.0394   0.059  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 204  0.0187  0.0346  0.0168  0.0177  0.0393   0.163  0.2028  0.1694  0.2328
# 205  0.0323  0.0101  0.0298  0.0564   0.076  0.0958   0.099  0.1018   0.103
# 206  0.0522  0.0437   0.018  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 207  0.0303  0.0353   0.049  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 208   0.026  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655    0.14  0.1843
#
#          9   ...      50      51      52      53      54      55      56  \
# 1    0.2111  ...  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167   0.018
# 2    0.2872  ...  0.0125  0.0084  0.0089  0.0048  0.0094  0.0191   0.014
# 3    0.6194  ...  0.0033  0.0232  0.0166  0.0095   0.018  0.0244  0.0316
# 4    0.1264  ...  0.0241  0.0121  0.0036   0.015  0.0085  0.0073   0.005
# 5    0.4459  ...  0.0156  0.0031  0.0054  0.0105   0.011  0.0015  0.0072
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 204  0.2684  ...  0.0203  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065
# 205  0.2154  ...  0.0051  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034
# 206  0.2529  ...  0.0155   0.016  0.0029  0.0051  0.0062  0.0089   0.014
# 207  0.2354  ...  0.0042  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034
# 208  0.2354  ...  0.0181  0.0146  0.0129  0.0047  0.0039  0.0061   0.004
#
#          57      58      59
# 1    0.0084   0.009  0.0032
# 2    0.0049  0.0052  0.0044
# 3    0.0164  0.0095  0.0078
# 4    0.0044   0.004  0.0117
# 5    0.0048  0.0107  0.0094
# ..      ...     ...     ...
# 204  0.0115  0.0193  0.0157
# 205  0.0032  0.0062  0.0067
# 206  0.0138  0.0077  0.0031
# 207  0.0079  0.0036  0.0048
# 208  0.0036  0.0061  0.0115
#
# [208 rows x 60 columns]
# 1      R
# 2      R
# 3      R
# 4      R
# 5      R
#       ..
# 204    M
# 205    M
# 206    M
# 207    M
# 208    M
# Name: 60, Length: 208, dtype: object

# %% [markdown]
# **Training and Test data**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, stratify=Y, random_state=1)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (208, 60) (187, 60) (21, 60)

# %%
print(X_train)
print(Y_train)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 116  0.0414  0.0436  0.0447  0.0844  0.0419  0.1215  0.2002  0.1516  0.0818
# 39   0.0123  0.0022  0.0196  0.0206   0.018  0.0492  0.0033  0.0398  0.0791
# 57   0.0152  0.0102  0.0113  0.0263  0.0097  0.0391  0.0857  0.0915  0.0949
# 124   0.027  0.0163  0.0341  0.0247  0.0822  0.1256  0.1323  0.1584  0.2017
# 19    0.027  0.0092  0.0145  0.0278  0.0412  0.0757  0.1026  0.1138  0.0794
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 141  0.0412  0.1135  0.0518  0.0232  0.0646  0.1124  0.1787  0.2407  0.2682
# 6    0.0286  0.0453  0.0277  0.0174  0.0384   0.099  0.1201  0.1833  0.2105
# 155  0.0117  0.0069  0.0279  0.0583  0.0915  0.1267  0.1577  0.1927  0.2361
# 132   0.115  0.1163  0.0866  0.0358  0.0232  0.1267  0.2417  0.2661  0.4346
# 204  0.0187  0.0346  0.0168  0.0177  0.0393   0.163  0.2028  0.1694  0.2328
#
#          9   ...      50      51      52      53      54      55      56  \
# 116  0.1975  ...  0.0222  0.0045  0.0136  0.0113  0.0053  0.0165  0.0141
# 39   0.0475  ...  0.0149  0.0125  0.0134  0.0026  0.0038  0.0018  0.0113
# 57   0.1504  ...  0.0048  0.0049  0.0041  0.0036  0.0013  0.0046  0.0037
# 124  0.2122  ...  0.0197  0.0189  0.0204  0.0085  0.0043  0.0092  0.0138
# 19    0.152  ...  0.0045  0.0084   0.001  0.0018  0.0068  0.0039   0.012
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 141  0.2058  ...  0.0798  0.0376  0.0143  0.0272  0.0127  0.0166  0.0095
# 6    0.3039  ...  0.0104  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057
# 155  0.2169  ...  0.0039  0.0053  0.0029   0.002  0.0013  0.0029   0.002
# 132  0.5378  ...  0.0228  0.0099  0.0065  0.0085  0.0166   0.011   0.019
# 204  0.2684  ...  0.0203  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065
#
#          57      58      59
# 116  0.0077  0.0246  0.0198
# 39   0.0058  0.0047  0.0071
# 57   0.0011  0.0034  0.0033
# 124  0.0094  0.0105  0.0093
# 19   0.0132   0.007  0.0088
# ..      ...     ...     ...
# 141  0.0225  0.0098  0.0085
# 6    0.0027  0.0051  0.0062
# 155  0.0062  0.0026  0.0052
# 132  0.0141  0.0068  0.0086
# 204  0.0115  0.0193  0.0157
#
# [187 rows x 60 columns]
# 116    M
# 39     R
# 57     R
# 124    M
# 19     R
#       ..
# 141    M
# 6      R
# 155    M
# 132    M
# 204    M
# Name: 60, Length: 187, dtype: object

# %% [markdown]
# **Model Training --> Logistic Regression**

# %%
model = LogisticRegression()

# %%
#training the Logisitic Regression model with training data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# **Model Evaluation**

# %%
#accuracy on the training Data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy on training data : " , training_data_accuracy)
# Out:
# Accuracy on training data :  0.8342245989304813

# %%
#accuracy on the training Data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print("Accuracy on test data : " , test_data_accuracy)
# Out:
# Accuracy on test data :  0.7619047619047619

# %% [markdown]
# **Making a Predictive System**

# %%
input_data = (0.0629,0.1065,0.1526,0.1229,0.1437,0.119,0.0884,0.0907,0.2107,0.3597,0.5466,0.5205,0.5127,0.5395,0.6558,0.8705,0.9786,0.9335,0.7917,0.7383,0.6908,0.385,0.0671,0.0502,0.2717,0.2839,0.2234,0.1911,0.0408,0.2531,0.1979,0.1891,0.2433,0.1956,0.2667,0.134,0.1073,0.2023,0.1794,0.0227,0.1313,0.1775,0.1549,0.1626,0.0708,0.0129,0.0795,0.0762,0.0117,0.0061,0.0257,0.0089,0.0262,0.0108,0.0138,0.0187,0.023,0.0057,0.0113,0.0131)

# changing the input_data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the np array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if(prediction[0]=='R'):
    print('The object is a Rock')
else:
    print("The object is a Mine")
# Out:
# ['M']
# The object is a Mine
